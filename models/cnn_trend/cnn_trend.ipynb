# %% [markdown]
# # CNN Model for predicting trend

# %%
#imports
import numpy as np
from math import sqrt
from numpy import concatenate

import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.utils import shuffle

from matplotlib import pyplot
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

import pandas as pd
from pandas import read_csv
from pandas import DataFrame
from pandas import concat

import keras.utils
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Activation
from keras.layers import Dense
from keras.layers import Convolution1D, Conv1D, ZeroPadding1D, MaxPooling1D, BatchNormalization, Activation, Dropout, Flatten, Dense
from keras.optimizers import Adam

import tensorflow as tf
import seaborn as sn
import seed
import os
tf.get_logger().setLevel('ERROR')

# %%
"""
method to create lagged features

data - data
to_keep - number of lagged_features
to_remove - number of days to remove

"""
def create_lagged_features(data, to_keep=1, to_remove=1):
    variables = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    columns, names = list(), list()
    
    for i in range(to_keep, 0, -1):
        columns.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(variables)]

    for i in range(0, to_remove):
        columns.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(variables)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(variables)]
            
    #put it all together
    final = concat(columns, axis=1)
    final.columns = names
    
    #drop rows with NaN values
    final.dropna(inplace=True)
        
    return final

# %%
"""
function to calculate rsi

data - data
period - RSI period

"""
def rsi(data, period: int = 14):
    
    delta = data["Close"].diff()

    up, down = delta.copy(), delta.copy()
    up[up < 0] = 0
    down[down > 0] = 0

    gain = up.ewm(com=(period - 1), min_periods=period).mean()
    loss = down.abs().ewm(com=(period - 1), min_periods=period).mean()

    RS = gain / loss
    return 100 - (100 / (1 + RS))

# %%
#lag granularity - days or hours
lag_granularity = "days"
#lag value
lag = 1
# type of analyser - TextBlob or vader
analyser = "vader"
# analyser = "TextBlob"
#dataset grouped type - day or hour
dataset_grouped_by = "day"

# %%
#read dataset
folder = "./../../datasets/tweets_prices_volumes_sentiment/"+analyser+"/"+dataset_grouped_by+"_datasets/cleaned"
filename = folder+"/final_data_lag_"+lag_granularity+"_"+str(lag)+".csv" if (lag > 0) else folder+"/final_data_no_lag.csv"
df = pd.read_csv(filename)

# %%
#group by datetime
df = df.groupby('DateTime').agg(lambda x: x.mean())

# %%
#get change label
df["Change"] = (df["Close"] > df["Close"].shift(1)).astype(int)

add_RSI = False
add_longMAvg = False
add_shortMAvg = False

if(add_RSI):
    #calcualte RSI
    RSI = 14
    df['RSI'] = rsi(df, RSI)
    df = df.iloc[RSI:]

#calculate moving averages
if(add_shortMAvg):
    short_window = 9
    df['short_mavg'] = df.rolling(window=short_window)["Close"].mean()
    
if(add_longMAvg):
    long_window = 21
    df["long_mavg"] = df.rolling(window=long_window)["Close"].mean()
    
if(add_longMAvg):
    df = df.iloc[long_window:]
elif(add_RSI):
    df = df.iloc[RSI:]
elif(add_shortMAvg):
    df = df.iloc[short_window:]

# %%
#keep only wanted columns
features = ['Change', 'subjectivity', 'polarity','Tweet_vol','Volume_(BTC)'] if analyser == "Textblob" else ['Change', 'Close', 'pos_pol', 'neg_pol', 'Tweet_vol']

if(add_RSI):
    features.append("RSI")
    
if(add_longMAvg):
    features.append("long_mavg")
    
if(add_shortMAvg):
    features.append("short_mavg")

df = df[features]

# %%
#plot correlation matrix
sn.heatmap(df.corr(), annot=True)
plt.show()

# %%
#creating copy so that data is not loaded once again
df_copy = df.copy()

# %%
#number of previous records to consider for every example
n_lag = 7
#number of features
n_features = len(features)
#calculate total_features
total_features = n_lag*n_features

if(total_features == 0):
    total_features = n_features

# %%
#add lagged data to records
data_with_lagged = create_lagged_features(df_copy, n_lag, 1)
data_with_lagged = data_with_lagged.reset_index()
data_with_lagged = data_with_lagged.drop(['DateTime'], axis=1)

# %%
#shuffle data
np.random.seed(1)
#shuffle times 
shuffle_times = 3;
for j in range(0, shuffle_times+1):
    data_with_lagged = shuffle(data_with_lagged)

# %%
#divide df into train and test
train_ratio = 0.85
data_len = len(data_with_lagged)
train_size = int(data_len*train_ratio)

train = data_with_lagged.iloc[:train_size]
test = data_with_lagged.iloc[train_size:]

# %%
#prepare labels
train_y = train["var1(t)"].values
test_y = test["var1(t)"].values

train_y = train_y.reshape(len(train_y), 1)
test_y = test_y.reshape(len(test_y), 1)

# %%
#normalise features
xscaler = MinMaxScaler(feature_range=(0, 1))
train = xscaler.fit_transform(train)
test = xscaler.transform(test)

# %%
#prepare data
train_labels = train_y
test_labels = test_y

# %%
#remove the last set of values(data of time to be predicted)
train = train[:, :total_features]
test = test[:, :total_features]

# %%
#keep only prices array
train_X, train_y = train[:, :total_features], train_y[:, -1]
test_X, test_y = test[:, :total_features], test_y[:, -1]

# %%
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_lag, n_features))
test_X = test_X.reshape((test_X.shape[0], n_lag, n_features))

# %%
#set labels for training data to categorical
train_y = keras.utils.to_categorical(train_y, 2)

# %%
np.random.seed(1) 
tf.random.set_seed(1)

# design network
model = Sequential()
neurons = 32
epochs = 10000
dropout = 0.25
batch_size = 50
layers = 3
activ_func = "linear"

#add first layer
model.add(Conv1D(neurons, kernel_size=2, padding='same', input_shape=(train_X.shape[1], train_X.shape[2]), activation=activ_func))
model.add(MaxPooling1D(pool_size=2, padding='same'))
model.add(Dropout(dropout))

#add the other layers
for i in range(1, layers):
    model.add(Conv1D(neurons, kernel_size=2, padding='same', activation=activ_func))
    model.add(MaxPooling1D(pool_size=2, padding='same'))
    model.add(Dropout(dropout))


#flatten and add a dense layer and to output the prediction
model.add(Flatten())
model.add(Dense(2, activation="softmax"))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience =20)

# fit network
history = model.fit(train_X, train_y, epochs=epochs, batch_size=batch_size, verbose=0, shuffle=False,validation_split=0.2, callbacks=[callback])

# %%
dot_img_file = 'model.png'
tf.keras.utils.plot_model(model, to_file=dot_img_file, show_shapes=True)

# %%
#callback
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience =50)

# fit network
history = model.fit(train_X, train_y, epochs=epochs, batch_size=batch_size, verbose=2, shuffle=True,validation_split=0.2, callbacks=[callback])
# Out:
# Epoch 1/10000
# 7/7 - 1s - loss: 0.6999 - accuracy: 0.4950 - val_loss: 0.7002 - val_accuracy: 0.3553
# Epoch 2/10000
# 7/7 - 0s - loss: 0.6928 - accuracy: 0.5382 - val_loss: 0.6907 - val_accuracy: 0.5263
# Epoch 3/10000
# 7/7 - 1s - loss: 0.6941 - accuracy: 0.5249 - val_loss: 0.7063 - val_accuracy: 0.3816
# Epoch 4/10000
# 7/7 - 0s - loss: 0.6955 - accuracy: 0.4651 - val_loss: 0.6800 - val_accuracy: 0.6447
# Epoch 5/10000
# 7/7 - 0s - loss: 0.6958 - accuracy: 0.5017 - val_loss: 0.6774 - val_accuracy: 0.6447
# Epoch 6/10000
# 7/7 - 0s - loss: 0.6905 - accuracy: 0.5216 - val_loss: 0.6948 - val_accuracy: 0.4868
# Epoch 7/10000
# 7/7 - 0s - loss: 0.6902 - accuracy: 0.5316 - val_loss: 0.6801 - val_accuracy: 0.6447
# Epoch 8/10000
# 7/7 - 0s - loss: 0.6974 - accuracy: 0.5017 - val_loss: 0.6705 - val_accuracy: 0.6447
# Epoch 9/10000
# 7/7 - 0s - loss: 0.6939 - accuracy: 0.5017 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 10/10000
# 7/7 - 0s - loss: 0.6935 - accuracy: 0.4817 - val_loss: 0.7100 - val_accuracy: 0.3553
# Epoch 11/10000
# 7/7 - 0s - loss: 0.6912 - accuracy: 0.5150 - val_loss: 0.6908 - val_accuracy: 0.5000
# Epoch 12/10000
# 7/7 - 0s - loss: 0.6915 - accuracy: 0.5150 - val_loss: 0.6713 - val_accuracy: 0.6447
# Epoch 13/10000
# 7/7 - 0s - loss: 0.6969 - accuracy: 0.5017 - val_loss: 0.6601 - val_accuracy: 0.6447
# Epoch 14/10000
# 7/7 - 0s - loss: 0.6968 - accuracy: 0.5017 - val_loss: 0.6728 - val_accuracy: 0.6447
# Epoch 15/10000
# 7/7 - 0s - loss: 0.6913 - accuracy: 0.5150 - val_loss: 0.6974 - val_accuracy: 0.4342
# Epoch 16/10000
# 7/7 - 0s - loss: 0.6912 - accuracy: 0.5748 - val_loss: 0.7258 - val_accuracy: 0.4342
# Epoch 17/10000
# 7/7 - 0s - loss: 0.6879 - accuracy: 0.5449 - val_loss: 0.6780 - val_accuracy: 0.5658
# Epoch 18/10000
# 7/7 - 0s - loss: 0.6961 - accuracy: 0.4983 - val_loss: 0.6631 - val_accuracy: 0.6316
# Epoch 19/10000
# 7/7 - 1s - loss: 0.7079 - accuracy: 0.5116 - val_loss: 0.7053 - val_accuracy: 0.4605
# Epoch 20/10000
# 7/7 - 0s - loss: 0.6977 - accuracy: 0.5382 - val_loss: 0.7270 - val_accuracy: 0.3553
# Epoch 21/10000
# 7/7 - 1s - loss: 0.6926 - accuracy: 0.4884 - val_loss: 0.6809 - val_accuracy: 0.5789
# Epoch 22/10000
# 7/7 - 0s - loss: 0.7074 - accuracy: 0.4718 - val_loss: 0.6908 - val_accuracy: 0.5921
# Epoch 23/10000
# 7/7 - 0s - loss: 0.6933 - accuracy: 0.4983 - val_loss: 0.7211 - val_accuracy: 0.3684
# Epoch 24/10000
# 7/7 - 0s - loss: 0.6926 - accuracy: 0.5415 - val_loss: 0.6922 - val_accuracy: 0.4868
# Epoch 25/10000
# 7/7 - 1s - loss: 0.6940 - accuracy: 0.5150 - val_loss: 0.6800 - val_accuracy: 0.6447
# Epoch 26/10000
# 7/7 - 1s - loss: 0.6929 - accuracy: 0.5282 - val_loss: 0.6916 - val_accuracy: 0.5263
# Epoch 27/10000
# 7/7 - 1s - loss: 0.6911 - accuracy: 0.5116 - val_loss: 0.6899 - val_accuracy: 0.5395
# Epoch 28/10000
# 7/7 - 1s - loss: 0.6924 - accuracy: 0.5017 - val_loss: 0.6835 - val_accuracy: 0.5921
# Epoch 29/10000
# 7/7 - 1s - loss: 0.6915 - accuracy: 0.5050 - val_loss: 0.6964 - val_accuracy: 0.4868
# Epoch 30/10000
# 7/7 - 1s - loss: 0.6887 - accuracy: 0.5449 - val_loss: 0.6885 - val_accuracy: 0.5526
# Epoch 31/10000
# 7/7 - 1s - loss: 0.6895 - accuracy: 0.5282 - val_loss: 0.6811 - val_accuracy: 0.6316
# Epoch 32/10000
# 7/7 - 1s - loss: 0.6889 - accuracy: 0.5316 - val_loss: 0.6881 - val_accuracy: 0.5000
# Epoch 33/10000
# 7/7 - 1s - loss: 0.6873 - accuracy: 0.5316 - val_loss: 0.6952 - val_accuracy: 0.4737
# Epoch 34/10000
# 7/7 - 1s - loss: 0.6854 - accuracy: 0.5681 - val_loss: 0.7489 - val_accuracy: 0.4342
# Epoch 35/10000
# 7/7 - 1s - loss: 0.7148 - accuracy: 0.5282 - val_loss: 0.7376 - val_accuracy: 0.4342
# Epoch 36/10000
# 7/7 - 1s - loss: 0.6870 - accuracy: 0.5615 - val_loss: 0.7065 - val_accuracy: 0.4474
# Epoch 37/10000
# 7/7 - 1s - loss: 0.6849 - accuracy: 0.5581 - val_loss: 0.7299 - val_accuracy: 0.4342
# Epoch 38/10000
# 7/7 - 1s - loss: 0.6875 - accuracy: 0.5382 - val_loss: 0.7515 - val_accuracy: 0.3947
# Epoch 39/10000
# 7/7 - 1s - loss: 0.6922 - accuracy: 0.5449 - val_loss: 0.7202 - val_accuracy: 0.4605
# Epoch 40/10000
# 7/7 - 1s - loss: 0.6937 - accuracy: 0.5681 - val_loss: 0.6969 - val_accuracy: 0.4868
# Epoch 41/10000
# 7/7 - 1s - loss: 0.6860 - accuracy: 0.5482 - val_loss: 0.7436 - val_accuracy: 0.3553
# Epoch 42/10000
# 7/7 - 1s - loss: 0.7015 - accuracy: 0.5216 - val_loss: 0.7290 - val_accuracy: 0.3816
# Epoch 43/10000
# 7/7 - 1s - loss: 0.6851 - accuracy: 0.5316 - val_loss: 0.6839 - val_accuracy: 0.6447
# Epoch 44/10000
# 7/7 - 1s - loss: 0.6890 - accuracy: 0.5316 - val_loss: 0.6934 - val_accuracy: 0.5132
# Epoch 45/10000
# 7/7 - 1s - loss: 0.6906 - accuracy: 0.5150 - val_loss: 0.6991 - val_accuracy: 0.5000
# Epoch 46/10000
# 7/7 - 1s - loss: 0.6923 - accuracy: 0.5548 - val_loss: 0.7135 - val_accuracy: 0.4211
# Epoch 47/10000
# 7/7 - 1s - loss: 0.6925 - accuracy: 0.5282 - val_loss: 0.6855 - val_accuracy: 0.5658
# Epoch 48/10000
# 7/7 - 1s - loss: 0.6897 - accuracy: 0.5249 - val_loss: 0.6730 - val_accuracy: 0.6447
# Epoch 49/10000
# 7/7 - 1s - loss: 0.6938 - accuracy: 0.5216 - val_loss: 0.6736 - val_accuracy: 0.6053
# Epoch 50/10000
# 7/7 - 1s - loss: 0.6928 - accuracy: 0.5316 - val_loss: 0.6804 - val_accuracy: 0.5658
# Epoch 51/10000
# 7/7 - 1s - loss: 0.6887 - accuracy: 0.5216 - val_loss: 0.6757 - val_accuracy: 0.5921
# Epoch 52/10000
# 7/7 - 1s - loss: 0.6918 - accuracy: 0.5282 - val_loss: 0.7045 - val_accuracy: 0.4342
# Epoch 53/10000
# 7/7 - 1s - loss: 0.6877 - accuracy: 0.5681 - val_loss: 0.6861 - val_accuracy: 0.6316
# Epoch 54/10000
# 7/7 - 1s - loss: 0.6900 - accuracy: 0.5449 - val_loss: 0.6761 - val_accuracy: 0.6447
# Epoch 55/10000
# 7/7 - 1s - loss: 0.6932 - accuracy: 0.5017 - val_loss: 0.6651 - val_accuracy: 0.6447
# Epoch 56/10000
# 7/7 - 1s - loss: 0.7012 - accuracy: 0.5017 - val_loss: 0.6599 - val_accuracy: 0.6447
# Epoch 57/10000
# 7/7 - 1s - loss: 0.7077 - accuracy: 0.5017 - val_loss: 0.6598 - val_accuracy: 0.6447
# Epoch 58/10000
# 7/7 - 1s - loss: 0.6949 - accuracy: 0.4983 - val_loss: 0.6721 - val_accuracy: 0.6316
# Epoch 59/10000
# 7/7 - 1s - loss: 0.6824 - accuracy: 0.5482 - val_loss: 0.6934 - val_accuracy: 0.4605
# Epoch 60/10000
# 7/7 - 1s - loss: 0.6827 - accuracy: 0.6213 - val_loss: 0.6903 - val_accuracy: 0.5395
# Epoch 61/10000
# 7/7 - 1s - loss: 0.6810 - accuracy: 0.5847 - val_loss: 0.7033 - val_accuracy: 0.4605
# Epoch 62/10000
# 7/7 - 1s - loss: 0.6725 - accuracy: 0.5947 - val_loss: 0.7317 - val_accuracy: 0.5263
# Epoch 63/10000
# 7/7 - 1s - loss: 0.7074 - accuracy: 0.5648 - val_loss: 0.6975 - val_accuracy: 0.5000
# Epoch 64/10000
# 7/7 - 1s - loss: 0.6799 - accuracy: 0.5449 - val_loss: 0.6831 - val_accuracy: 0.5658
# Epoch 65/10000
# 7/7 - 1s - loss: 0.6910 - accuracy: 0.5282 - val_loss: 0.6675 - val_accuracy: 0.6184
# Epoch 66/10000
# 7/7 - 1s - loss: 0.6822 - accuracy: 0.5748 - val_loss: 0.7028 - val_accuracy: 0.5132
# Epoch 67/10000
# 7/7 - 1s - loss: 0.6827 - accuracy: 0.5814 - val_loss: 0.6863 - val_accuracy: 0.5658
# Epoch 68/10000
# 7/7 - 1s - loss: 0.6841 - accuracy: 0.5748 - val_loss: 0.6894 - val_accuracy: 0.5263
# Epoch 69/10000
# 7/7 - 1s - loss: 0.6808 - accuracy: 0.5748 - val_loss: 0.7341 - val_accuracy: 0.4605
# Epoch 70/10000
# 7/7 - 1s - loss: 0.7000 - accuracy: 0.5548 - val_loss: 0.7320 - val_accuracy: 0.4605
# Epoch 71/10000
# 7/7 - 1s - loss: 0.6787 - accuracy: 0.5847 - val_loss: 0.6859 - val_accuracy: 0.6053
# Epoch 72/10000
# 7/7 - 1s - loss: 0.6952 - accuracy: 0.5183 - val_loss: 0.6747 - val_accuracy: 0.6053
# Epoch 73/10000
# 7/7 - 1s - loss: 0.6814 - accuracy: 0.5415 - val_loss: 0.6926 - val_accuracy: 0.4474
# Epoch 74/10000
# 7/7 - 1s - loss: 0.6805 - accuracy: 0.5748 - val_loss: 0.7093 - val_accuracy: 0.4737
# Epoch 75/10000
# 7/7 - 1s - loss: 0.6804 - accuracy: 0.5880 - val_loss: 0.6975 - val_accuracy: 0.4737
# Epoch 76/10000
# 7/7 - 1s - loss: 0.6781 - accuracy: 0.5880 - val_loss: 0.7112 - val_accuracy: 0.4605
# Epoch 77/10000
# 7/7 - 1s - loss: 0.6807 - accuracy: 0.5748 - val_loss: 0.7362 - val_accuracy: 0.4605
# Epoch 78/10000
# 7/7 - 1s - loss: 0.6757 - accuracy: 0.5648 - val_loss: 0.7119 - val_accuracy: 0.5395
# Epoch 79/10000
# 7/7 - 1s - loss: 0.6960 - accuracy: 0.5349 - val_loss: 0.7046 - val_accuracy: 0.4868
# Epoch 80/10000
# 7/7 - 1s - loss: 0.6917 - accuracy: 0.5482 - val_loss: 0.7221 - val_accuracy: 0.4474
# Epoch 81/10000
# 7/7 - 1s - loss: 0.6848 - accuracy: 0.5581 - val_loss: 0.7102 - val_accuracy: 0.4474
# Epoch 82/10000
# 7/7 - 1s - loss: 0.6856 - accuracy: 0.5615 - val_loss: 0.7074 - val_accuracy: 0.4474
# Epoch 83/10000
# 7/7 - 1s - loss: 0.6862 - accuracy: 0.5681 - val_loss: 0.6963 - val_accuracy: 0.4737
# Epoch 84/10000
# 7/7 - 1s - loss: 0.6841 - accuracy: 0.5714 - val_loss: 0.7064 - val_accuracy: 0.4474
# Epoch 85/10000
# 7/7 - 1s - loss: 0.6835 - accuracy: 0.5681 - val_loss: 0.7148 - val_accuracy: 0.4474
# Epoch 86/10000
# 7/7 - 1s - loss: 0.6852 - accuracy: 0.5814 - val_loss: 0.6842 - val_accuracy: 0.5789
# Epoch 87/10000
# 7/7 - 1s - loss: 0.6890 - accuracy: 0.4983 - val_loss: 0.6771 - val_accuracy: 0.6447
# Epoch 88/10000
# 7/7 - 1s - loss: 0.6867 - accuracy: 0.5282 - val_loss: 0.6885 - val_accuracy: 0.4342
# Epoch 89/10000
# 7/7 - 1s - loss: 0.6806 - accuracy: 0.5615 - val_loss: 0.6889 - val_accuracy: 0.4737
# Epoch 90/10000
# 7/7 - 1s - loss: 0.6806 - accuracy: 0.5482 - val_loss: 0.7498 - val_accuracy: 0.4474
# Epoch 91/10000
# 7/7 - 1s - loss: 0.6948 - accuracy: 0.5548 - val_loss: 0.6798 - val_accuracy: 0.5526
# Epoch 92/10000
# 7/7 - 1s - loss: 0.6827 - accuracy: 0.5349 - val_loss: 0.6682 - val_accuracy: 0.6447
# Epoch 93/10000
# 7/7 - 1s - loss: 0.6858 - accuracy: 0.5183 - val_loss: 0.6647 - val_accuracy: 0.6447
# Epoch 94/10000
# 7/7 - 1s - loss: 0.6850 - accuracy: 0.5050 - val_loss: 0.6725 - val_accuracy: 0.6184
# Epoch 95/10000
# 7/7 - 1s - loss: 0.6904 - accuracy: 0.5183 - val_loss: 0.6950 - val_accuracy: 0.5526
# Epoch 96/10000
# 7/7 - 1s - loss: 0.6795 - accuracy: 0.5914 - val_loss: 0.7450 - val_accuracy: 0.4342
# Epoch 97/10000
# 7/7 - 1s - loss: 0.6737 - accuracy: 0.5615 - val_loss: 0.7151 - val_accuracy: 0.4868
# Epoch 98/10000
# 7/7 - 1s - loss: 0.6773 - accuracy: 0.5814 - val_loss: 0.7446 - val_accuracy: 0.4868
# Epoch 99/10000
# 7/7 - 1s - loss: 0.6915 - accuracy: 0.5449 - val_loss: 0.7223 - val_accuracy: 0.5132
# Epoch 100/10000
# 7/7 - 1s - loss: 0.6882 - accuracy: 0.5449 - val_loss: 0.7226 - val_accuracy: 0.4474
# Epoch 101/10000
# 7/7 - 1s - loss: 0.6802 - accuracy: 0.5581 - val_loss: 0.7243 - val_accuracy: 0.4474
# Epoch 102/10000
# 7/7 - 1s - loss: 0.6812 - accuracy: 0.5581 - val_loss: 0.7148 - val_accuracy: 0.5000
# Epoch 103/10000
# 7/7 - 1s - loss: 0.6869 - accuracy: 0.5548 - val_loss: 0.7050 - val_accuracy: 0.4737
# Epoch 104/10000
# 7/7 - 1s - loss: 0.6885 - accuracy: 0.5615 - val_loss: 0.7090 - val_accuracy: 0.5132
# Epoch 105/10000
# 7/7 - 1s - loss: 0.6852 - accuracy: 0.5581 - val_loss: 0.7299 - val_accuracy: 0.4474
# Epoch 106/10000
# 7/7 - 1s - loss: 0.6756 - accuracy: 0.5914 - val_loss: 0.7594 - val_accuracy: 0.4342
# Epoch 107/10000
# 7/7 - 1s - loss: 0.6912 - accuracy: 0.5515 - val_loss: 0.7375 - val_accuracy: 0.4342

# %%
#plot loss graph
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.title("Loss graph")
plt.show()

# %%
#plot training and validation accuracy
loss_train = history.history['accuracy']
loss_val = history.history['val_accuracy']
epochs = range(1,len(loss_val) + 1)
plt.plot(epochs, loss_train, 'g', label='Training accuracy')
plt.plot(epochs, loss_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#reshape
test_X = test_X.reshape((test_X.shape[0], n_lag, n_features))

#predict values for test data
pred = model.predict(test_X)

#reshape again
test_X = test_X.reshape((test_X.shape[0], n_lag* n_features,))

# %%
#change back from categorical
pred = np.argmax(pred, axis=1)

# %%
#calculate accuracy
prices = pd.DataFrame()
prices["Actual"] = test_y
prices["Predicted"] = pred

prices["Correct"] = (prices["Actual"] - prices["Predicted"]) == 0
incorrect = prices.loc[prices['Correct'] == False]
incorrect_len = len(incorrect)
prices_len = len(prices)

print("Accuracy = ",((prices_len-incorrect_len)/prices_len))
# Out:
# Accuracy =  0.6119402985074627
