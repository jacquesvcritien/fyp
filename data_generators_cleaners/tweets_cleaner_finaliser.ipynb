# %% [markdown]
# # This notebook pre-processes tweets
#
# ### It does the following:
# 1. Removes records whose tweet text is reduced to less than 4 words because sentiment cannot be absorbed

# %%
import pandas as pd
import nltk
from nltk import word_tokenize, sent_tokenize, FreqDist
from nltk.corpus import stopwords
from nltk.corpus import words
from nltk.stem import LancasterStemmer, WordNetLemmatizer
from nltk.tokenize.treebank import TreebankWordDetokenizer
from nltk.tokenize import TweetTokenizer
import re
import threading
import langdetect as ld
from nltk.corpus import words
import numpy as np
import shutil

# %%
tweet_data = pd.read_csv("../datasets/general/preprocessed_tweets.csv")
# Out:
# C:\Users\dell\Anaconda3\envs\fyp\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
tweet_data
# Out:
#           Unnamed: 0  Unnamed: 0.1     index            id             user  \
# 0                  0             1         1  1.132977e+18        bitcointe
# 1                  1             2         2  1.132977e+18        3eyedbran
# 2                  2             3         3  1.132977e+18    DetroitCrypto
# 3                  3             4         4  1.132977e+18     mmursaleen72
# 4                  4             6         6  1.132977e+18     evilrobotted
# ...              ...           ...       ...           ...              ...
# 11912995       11908      15638947  20165006  1.198261e+18           iceXzi
# 11912996       11909      15638948  20165007  1.198266e+18    digital_mine_
# 11912997       11910      15638949  20165008  1.198262e+18    JacobCanfield
# 11912998       11911      15638951  20165010  1.198266e+18         torusJKL
# 11912999       11912      15638952  20165011  1.198266e+18  Adekunl95628158
#
# ...

# %%
def count_words(sentence):
    sentence = str(sentence)
    return len(sentence.split())

# %%
#remove tweets with less than 3 tweets
tweet_data = tweet_data[tweet_data['text'].map(count_words) > 3]

# %%
#delete folder with tweets which was used for preprocessing
shutil.rmtree("./../datasets/cleaned_tweets")

# %%
tweet_data.to_csv("./../datasets/general/tweets_cleaned.csv")
